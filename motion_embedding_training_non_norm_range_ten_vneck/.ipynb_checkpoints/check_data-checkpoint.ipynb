# %%
import os
import matplotlib
matplotlib.use("Agg")
import numpy as np
from numpy import pi
import tensorflow as tf
import matplotlib.pyplot as plt
import scipy.io as sio
import cv2
import logging,argparse
from data_loader import Data_loader
import model
from hyperparams import Hyperparameters
import utils
from commons import tf_transform
import graph
from termcolor import colored



import model_componets as comps
from commons import transform_util
H = Hyperparameters ()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0421 17:17:11.337506 140489973536576 deprecation_wrapper.py:119] From model.py:10: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
# Tensor("Const:0", shape=(3,), dtype=float32)
# Tensor("Const_1:0", shape=(17, 3), dtype=float32)

# %%
k= sio.loadmat('./')
poses = k['pose_3d']

# %%
# %matplotlib inline
fig = plt.figure(figsize=(16, 8))

fig_img = utils.gen_plot(fig, poses[:H.seq_length].reshape([H.seq_length, H.num_joints, 3]), poses[:H.seq_length].reshape([H.seq_length, H.num_joints, 3]), az=90)

# %%
from vi
